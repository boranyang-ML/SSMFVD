# %%
import os

# %%
# switch to the path where the dataset is stored
# %cd /content/drive/MyDrive/dataset_images/
# Out:
# /content/drive/MyDrive/dataset_images

# %% [markdown]
# Don't forget to modify my_dataset.py when you want to change the dataset

# %%
# copy the zip file (dataset) to the /content directory

#!cp SSMFVD.zip /content
# !cp kaggle.zip /content
#!cp PWMFD.zip /content

# %%
# # switch to content directory
# %cd /content
# unzip
#!unzip SSMFVD.zip -d '/content/dataset'
# !unzip kaggle.zip -d '/content/dataset'
#!unzip PWMFD.zip -d '/content/dataset'

# %%
# switch to the path where the dataset txt files are stored

#%cd /content/drive/MyDrive/TrainingStage2/data/SSMFVD_dataset_txt/

# %cd /content/drive/MyDrive/TrainingStage2/data/kaggle_dataset_txt

#%cd /content/drive/MyDrive/TrainingStage2/data/PWMFD_dataset_txt
# Out:
# /content/drive/MyDrive/faster_rcnn/data/kaggle_dataset_txt

# %%
# copy the txt files to /content/dataset/
# !cp train.txt /content/dataset/ #
# !cp valid.txt /content/dataset/ #
# !cp test.txt /content/dataset/ #

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Nov  2 14:13:13 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import sys
print(sys.path)
sys.path.append('/content/drive/MyDrive/TrainingStage2/')
# print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']

# %%
import os
import datetime

import torch
import torchvision

import transforms
from network_files import FasterRCNN, FastRCNNPredictor
from backbone import resnet50_fpn_backbone
from my_dataset import MyDataSet
from train_utils import GroupedBatchSampler, create_aspect_ratio_groups
from train_utils import train_eval_utils as utils

# %%
def create_model(num_classes, load_pretrain_weights=True): # True
    # trainable_layers includes ['layer4', 'layer3', 'layer2', 'layer1', 'conv1']
    # resnet50 imagenet weights url: https://download.pytorch.org/models/resnet50-0676ba61.pth
    backbone = resnet50_fpn_backbone(#pretrain_path="/content/drive/MyDrive/TrainingStage2/backbone/P2O-nobottle-Otarget-9631-supervised-Notrack.pth", # SSMFVD best in stage1
                                     pretrain_path="/content/drive/MyDrive/TrainingStage2/backbone/P2K-nobottle-Ktarget-9804-supervised.pth", # kaggle best in stage1
                                     norm_layer= torchvision.ops.FrozenBatchNorm2d, # torchvision.ops.FrozenBatchNorm2d, torch.nn.BatchNorm2d
                                     trainable_layers=3)
    # 90+1 or 3+1, set it as 4 when you load your own model，otherwise 91
    model = FasterRCNN(backbone=backbone, num_classes=91) 
    
    if load_pretrain_weights:
        # load pre-trained weights
        # https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
        weights_dict = torch.load("/content/drive/MyDrive/TrainingStage2/backbone/fasterrcnn_resnet50_fpn_coco.pth", map_location='cpu')
        #weights_dict = weights_dict["model"]
        missing_keys, unexpected_keys = model.load_state_dict(weights_dict, strict=False)
        if len(missing_keys) != 0 or len(unexpected_keys) != 0:
            print("missing_keys: ", missing_keys)
            print("unexpected_keys: ", unexpected_keys)

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    return model

# %%
def main(args):
    device = torch.device(args.device if torch.cuda.is_available() else "cpu")
    print("Using {} device training.".format(device.type))

    results_file = "/content/drive/MyDrive/TrainingStage2/save_weights/results{}.txt".format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

    data_transform = {
        "train": transforms.Compose([transforms.ToTensor(),
                                     transforms.RandomHorizontalFlip(0.5)]),
        "val": transforms.Compose([transforms.ToTensor()])
    }

    ##############################################################################
    mydataset = args.data_path
    # check dataset root
    if os.path.exists(mydataset) is False:
        raise FileNotFoundError("MyDataSet dose not in path:'{}'.".format(mydataset))

    # load train data set
    # /content/dataset/train.txt
    train_dataset = MyDataSet(mydataset, "train", data_transform["train"], "train.txt")
    train_sampler = None
    ##############################################################################

    if args.aspect_ratio_group_factor >= 0:
        train_sampler = torch.utils.data.RandomSampler(train_dataset)
        group_ids = create_aspect_ratio_groups(train_dataset, k=args.aspect_ratio_group_factor)
        train_batch_sampler = GroupedBatchSampler(train_sampler, group_ids, args.batch_size)

    batch_size = args.batch_size
    nw = min([os.cpu_count(), batch_size if batch_size > 1 else 0, 8])  # number of workers
    print('Using %g dataloader workers' % nw)
    if train_sampler:
        train_data_loader = torch.utils.data.DataLoader(train_dataset,
                                                        batch_sampler=train_batch_sampler,
                                                        pin_memory=True,
                                                        num_workers=nw,
                                                        collate_fn=train_dataset.collate_fn)
    else:
        train_data_loader = torch.utils.data.DataLoader(train_dataset,
                                                        batch_size=batch_size,
                                                        shuffle=True,
                                                        pin_memory=True,
                                                        num_workers=nw,
                                                        collate_fn=train_dataset.collate_fn)

    ###############################################---validation--###############################
    # load validation data set
    # /content/dataset/valid.txt
    val_dataset = MyDataSet(mydataset, "valid", data_transform["val"], "valid.txt")
    val_data_set_loader = torch.utils.data.DataLoader(val_dataset,
                                                      batch_size=1,
                                                      shuffle=False,
                                                      pin_memory=True,
                                                      num_workers=nw,
                                                      collate_fn=val_dataset.collate_fn)
    ###############################################---End--###############################

    # create model num_classes equal background + 20 classes
    model = create_model(num_classes=args.num_classes + 1)
    # print(model)

    model.to(device)

    # define optimizer
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.SGD(params,
                                lr=args.lr,
                                momentum=args.momentum,
                                weight_decay=args.weight_decay)

    scaler = torch.cuda.amp.GradScaler() if args.amp else None

    # learning rate scheduler
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                   step_size=3,
                                                   gamma=0.33)

    # resume
    if args.resume != "":
        checkpoint = torch.load(args.resume, map_location='cpu')
        model.load_state_dict(checkpoint['model'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        lr_scheduler.load_state_dict(checkpoint['lr_scheduler'])
        args.start_epoch = checkpoint['epoch'] + 1
        if args.amp and "scaler" in checkpoint:
            scaler.load_state_dict(checkpoint["scaler"])
        print("the training process from epoch{}...".format(args.start_epoch))

    train_loss = []
    learning_rate = []
    val_map_05 = []
    val_map_0595 = []

    for epoch in range(args.start_epoch, args.epochs):
        # train for one epoch, printing every 10 iterations
        mean_loss, lr = utils.train_one_epoch(model, optimizer, train_data_loader,
                                              device=device, epoch=epoch,
                                              print_freq=50, warmup=True,
                                              scaler=scaler)
        train_loss.append(mean_loss.item())
        learning_rate.append(lr)

        # update the learning rate
        lr_scheduler.step()

        # evaluate on the test dataset
        coco_info = utils.evaluate(model, val_data_set_loader, device=device)

        # write into txt
        with open(results_file, "a") as f:
            result_info = [f"{i:.4f}" for i in coco_info + [mean_loss.item()]] + [f"{lr:.6f}"]
            txt = "epoch:{} {}".format(epoch, '  '.join(result_info))
            f.write(txt + "\n")

        val_map_0595.append(coco_info[0])  # mAP @ IoU=0.50:0.95
        val_map_05.append(coco_info[1])  # mAP @ IoU=0.50

        # save weights
        save_files = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'lr_scheduler': lr_scheduler.state_dict(),
            'epoch': epoch}
        if args.amp:
            save_files["scaler"] = scaler.state_dict()
        torch.save(save_files, "/content/drive/MyDrive/TrainingStage2/save_weights/resNetFpn-model-{}.pth".format(epoch))

    # plot loss and lr curve
    if len(train_loss) != 0 and len(learning_rate) != 0:
        from plot_curve import plot_loss_and_lr
        plot_loss_and_lr(train_loss, learning_rate)

    # plot mAP curve
    if len(val_map_05) != 0 or len(val_map_0595) != 0:
        from plot_curve import plot_map
        plot_map(val_map_05, val_map_0595)

# %%
if __name__ == "__main__":
    import argparse

    parser = argparse.ArgumentParser(
        description=__doc__)

    parser.add_argument('--device', default='cuda:0', help='device')
    parser.add_argument('--data-path', default='/content/dataset/', help='dataset')
    parser.add_argument('--num-classes', default=3, type=int, help='num_classes')
    parser.add_argument('--output-dir', default='/content/drive/MyDrive/TrainingStage2/save_weights', help='path where to save')
    parser.add_argument('--resume', default='', type=str, help='resume from checkpoint')
    parser.add_argument('--start_epoch', default=0, type=int, help='start epoch')
    parser.add_argument('--epochs', default=30, type=int, metavar='N',help='number of total epochs to run')
    parser.add_argument('--lr', default=0.02, type=float,
                        help='initial learning rate, 0.02 is the default value for training '
                             'on 8 gpus and 2 images_per_gpu')
    parser.add_argument('--momentum', default=0.9, type=float, metavar='M',help='momentum')
    parser.add_argument('--wd', '--weight-decay', default=1e-4, type=float,
                        metavar='W', help='weight decay (default: 1e-4)',
                        dest='weight_decay')
    parser.add_argument('--batch_size', default=4, type=int, metavar='N',help='batch size when training.')
    parser.add_argument('--aspect-ratio-group-factor', default=3, type=int)
    parser.add_argument("--amp", default=False, help="Use torch.cuda.amp for mixed precision training")

    opt = parser.parse_args(args=[])
    print(opt)

    if not os.path.exists(opt.output_dir):
        os.makedirs(opt.output_dir)

    main(opt)
# Out:
# Namespace(amp=False, aspect_ratio_group_factor=3, batch_size=4, data_path='/content/dataset/', device='cuda:0', epochs=30, lr=0.02, momentum=0.9, num_classes=3, output_dir='/content/drive/MyDrive/faster_rcnn/save_weights', resume='', start_epoch=0, weight_decay=0.0001)
# Using cuda device training.
# Using [0, 0.5, 0.6299605249474366, 0.7937005259840997, 1.0, 1.2599210498948732, 1.5874010519681994, 2.0, inf] as bins for aspect ratio quantization
# Count of instances per bin: [  1   5 195   7  30 257 174  13]
# Using 4 dataloader workers
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['classifier_layer.weight', 'classifier_layer.bias'])
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch: [0]  [  0/170]  eta: 0:23:56.677535  lr: 0.000138  loss: 1.9164 (1.9164)  loss_classifier: 1.6895 (1.6895)  loss_box_reg: 0.1473 (0.1473)  loss_objectness: 0.0610 (0.0610)  loss_rpn_box_reg: 0.0186 (0.0186)  time: 8.4510  data: 0.2612  max mem: 4440
# Epoch: [0]  [ 50/170]  eta: 0:02:16.954283  lr: 0.006049  loss: 0.5435 (0.8501)  loss_classifier: 0.1360 (0.4398)  loss_box_reg: 0.3749 (0.3172)  loss_objectness: 0.0161 (0.0731)  loss_rpn_box_reg: 0.0165 (0.0200)  time: 1.0241  data: 0.0002  max mem: 5136
# Epoch: [0]  [100/170]  eta: 0:01:15.764743  lr: 0.011961  loss: 0.6004 (0.6497)  loss_classifier: 0.2342 (0.3020)  loss_box_reg: 0.3507 (0.2859)  loss_objectness: 0.0076 (0.0458)  loss_rpn_box_reg: 0.0080 (0.0160)  time: 1.0434  data: 0.0002  max mem: 5137
# Epoch: [0]  [150/170]  eta: 0:00:21.440864  lr: 0.017872  loss: 0.6063 (0.6107)  loss_classifier: 0.2417 (0.2605)  loss_box_reg: 0.3200 (0.2682)  loss_objectness: 0.0274 (0.0623)  loss_rpn_box_reg: 0.0172 (0.0196)  time: 1.0561  data: 0.0002  max mem: 5137
# Epoch: [0]  [169/170]  eta: 0:00:01.068092  lr: 0.020000  loss: 0.1351 (0.5890)  loss_classifier: 0.0588 (0.2484)  loss_box_reg: 0.0642 (0.2621)  loss_objectness: 0.0095 (0.0590)  loss_rpn_box_reg: 0.0027 (0.0195)  time: 1.0375  data: 0.0002  max mem: 5137
# Epoch: [0] Total time: 0:03:01 (1.0684 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.243647  model_time: 0.1092 (0.1092)  evaluator_time: 0.0031 (0.0031)  time: 0.2735  data: 0.1605  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.119285  model_time: 0.1076 (0.1112)  evaluator_time: 0.0017 (0.0058)  time: 0.1170  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1199 s / it)
# Averaged stats: model_time: 0.1076 (0.1112)  evaluator_time: 0.0017 (0.0058)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.229
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.403
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.405
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.495
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.664
# Epoch: [1]  [  0/170]  eta: 0:03:53.151355  lr: 0.020000  loss: 0.5649 (0.5649)  loss_classifier: 0.2160 (0.2160)  loss_box_reg: 0.2935 (0.2935)  loss_objectness: 0.0407 (0.0407)  loss_rpn_box_reg: 0.0147 (0.0147)  time: 1.3715  data: 0.2537  max mem: 5137
# Epoch: [1]  [ 50/170]  eta: 0:02:09.774814  lr: 0.020000  loss: 0.4970 (0.4186)  loss_classifier: 0.1506 (0.1441)  loss_box_reg: 0.3191 (0.2394)  loss_objectness: 0.0169 (0.0201)  loss_rpn_box_reg: 0.0104 (0.0151)  time: 1.0713  data: 0.0002  max mem: 5137
# Epoch: [1]  [100/170]  eta: 0:01:15.317087  lr: 0.020000  loss: 0.1499 (0.3852)  loss_classifier: 0.0655 (0.1341)  loss_box_reg: 0.0802 (0.2146)  loss_objectness: 0.0012 (0.0213)  loss_rpn_box_reg: 0.0031 (0.0151)  time: 1.0907  data: 0.0002  max mem: 5137
# Epoch: [1]  [150/170]  eta: 0:00:21.610546  lr: 0.020000  loss: 0.3609 (0.3749)  loss_classifier: 0.1479 (0.1327)  loss_box_reg: 0.1871 (0.2056)  loss_objectness: 0.0160 (0.0221)  loss_rpn_box_reg: 0.0099 (0.0145)  time: 1.0705  data: 0.0002  max mem: 5137
# Epoch: [1]  [169/170]  eta: 0:00:01.078977  lr: 0.020000  loss: 0.1478 (0.3696)  loss_classifier: 0.0464 (0.1300)  loss_box_reg: 0.0951 (0.2047)  loss_objectness: 0.0040 (0.0208)  loss_rpn_box_reg: 0.0023 (0.0140)  time: 1.0726  data: 0.0002  max mem: 5137
# Epoch: [1] Total time: 0:03:03 (1.0794 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.767877  model_time: 0.1111 (0.1111)  evaluator_time: 0.0023 (0.0023)  time: 0.2796  data: 0.1656  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.120639  model_time: 0.1101 (0.1123)  evaluator_time: 0.0014 (0.0060)  time: 0.1178  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1213 s / it)
# Averaged stats: model_time: 0.1101 (0.1123)  evaluator_time: 0.0014 (0.0060)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.613
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.725
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.759
# Epoch: [2]  [  0/170]  eta: 0:04:05.380943  lr: 0.020000  loss: 0.6692 (0.6692)  loss_classifier: 0.3036 (0.3036)  loss_box_reg: 0.3261 (0.3261)  loss_objectness: 0.0199 (0.0199)  loss_rpn_box_reg: 0.0197 (0.0197)  time: 1.4434  data: 0.2660  max mem: 5137
# Epoch: [2]  [ 50/170]  eta: 0:02:14.107961  lr: 0.020000  loss: 0.4735 (0.3711)  loss_classifier: 0.1499 (0.1275)  loss_box_reg: 0.3073 (0.2137)  loss_objectness: 0.0079 (0.0174)  loss_rpn_box_reg: 0.0084 (0.0124)  time: 1.1164  data: 0.0002  max mem: 5137
# Epoch: [2]  [100/170]  eta: 0:01:17.273569  lr: 0.020000  loss: 0.4753 (0.3356)  loss_classifier: 0.1631 (0.1113)  loss_box_reg: 0.2911 (0.1931)  loss_objectness: 0.0126 (0.0181)  loss_rpn_box_reg: 0.0085 (0.0131)  time: 1.0812  data: 0.0002  max mem: 5137
# Epoch: [2]  [150/170]  eta: 0:00:21.956285  lr: 0.020000  loss: 0.1825 (0.3157)  loss_classifier: 0.0455 (0.1049)  loss_box_reg: 0.1310 (0.1836)  loss_objectness: 0.0020 (0.0156)  loss_rpn_box_reg: 0.0041 (0.0115)  time: 1.0898  data: 0.0002  max mem: 5137
# Epoch: [2]  [169/170]  eta: 0:00:01.095637  lr: 0.020000  loss: 0.1137 (0.3103)  loss_classifier: 0.0385 (0.1042)  loss_box_reg: 0.0587 (0.1800)  loss_objectness: 0.0144 (0.0151)  loss_rpn_box_reg: 0.0022 (0.0110)  time: 1.0770  data: 0.0002  max mem: 5137
# Epoch: [2] Total time: 0:03:06 (1.0960 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:24.059316  model_time: 0.1105 (0.1105)  evaluator_time: 0.0018 (0.0018)  time: 0.2831  data: 0.1701  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.119427  model_time: 0.1095 (0.1142)  evaluator_time: 0.0012 (0.0028)  time: 0.1163  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1201 s / it)
# Averaged stats: model_time: 0.1095 (0.1142)  evaluator_time: 0.0012 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.589
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.313
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.464
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.741
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.610
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.773
# Epoch: [3]  [  0/170]  eta: 0:04:09.546492  lr: 0.006600  loss: 0.3361 (0.3361)  loss_classifier: 0.1004 (0.1004)  loss_box_reg: 0.1970 (0.1970)  loss_objectness: 0.0263 (0.0263)  loss_rpn_box_reg: 0.0124 (0.0124)  time: 1.4679  data: 0.2230  max mem: 5137
# Epoch: [3]  [ 50/170]  eta: 0:02:09.937746  lr: 0.006600  loss: 0.2549 (0.2402)  loss_classifier: 0.1163 (0.0800)  loss_box_reg: 0.1344 (0.1483)  loss_objectness: 0.0009 (0.0052)  loss_rpn_box_reg: 0.0034 (0.0067)  time: 1.0698  data: 0.0002  max mem: 5137
# Epoch: [3]  [100/170]  eta: 0:01:16.556427  lr: 0.006600  loss: 0.3249 (0.2561)  loss_classifier: 0.1292 (0.0870)  loss_box_reg: 0.1885 (0.1556)  loss_objectness: 0.0023 (0.0062)  loss_rpn_box_reg: 0.0050 (0.0073)  time: 1.1015  data: 0.0002  max mem: 5137
# Epoch: [3]  [150/170]  eta: 0:00:21.870273  lr: 0.006600  loss: 0.1902 (0.2481)  loss_classifier: 0.0419 (0.0832)  loss_box_reg: 0.1466 (0.1506)  loss_objectness: 0.0004 (0.0065)  loss_rpn_box_reg: 0.0014 (0.0079)  time: 1.0875  data: 0.0002  max mem: 5137
# Epoch: [3]  [169/170]  eta: 0:00:01.090530  lr: 0.006600  loss: 0.1859 (0.2441)  loss_classifier: 0.0527 (0.0817)  loss_box_reg: 0.1235 (0.1479)  loss_objectness: 0.0078 (0.0066)  loss_rpn_box_reg: 0.0020 (0.0079)  time: 1.0678  data: 0.0003  max mem: 5137
# Epoch: [3] Total time: 0:03:05 (1.0909 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.628834  model_time: 0.1101 (0.1101)  evaluator_time: 0.0014 (0.0014)  time: 0.2780  data: 0.1659  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.119547  model_time: 0.1109 (0.1143)  evaluator_time: 0.0008 (0.0028)  time: 0.1171  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1202 s / it)
# Averaged stats: model_time: 0.1109 (0.1143)  evaluator_time: 0.0008 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.661
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.480
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.370
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.561
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.756
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.531
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.584
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.677
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.778
# Epoch: [4]  [  0/170]  eta: 0:03:47.710047  lr: 0.006600  loss: 0.0508 (0.0508)  loss_classifier: 0.0116 (0.0116)  loss_box_reg: 0.0386 (0.0386)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 1.3395  data: 0.2274  max mem: 5137
# Epoch: [4]  [ 50/170]  eta: 0:02:13.159658  lr: 0.006600  loss: 0.4280 (0.2029)  loss_classifier: 0.1475 (0.0640)  loss_box_reg: 0.2222 (0.1273)  loss_objectness: 0.0365 (0.0038)  loss_rpn_box_reg: 0.0217 (0.0078)  time: 1.1046  data: 0.0002  max mem: 5137
# Epoch: [4]  [100/170]  eta: 0:01:16.908481  lr: 0.006600  loss: 0.3335 (0.2315)  loss_classifier: 0.1010 (0.0744)  loss_box_reg: 0.2023 (0.1435)  loss_objectness: 0.0164 (0.0052)  loss_rpn_box_reg: 0.0138 (0.0084)  time: 1.0746  data: 0.0002  max mem: 5137
# Epoch: [4]  [150/170]  eta: 0:00:21.797581  lr: 0.006600  loss: 0.1029 (0.2215)  loss_classifier: 0.0529 (0.0698)  loss_box_reg: 0.0485 (0.1401)  loss_objectness: 0.0008 (0.0046)  loss_rpn_box_reg: 0.0007 (0.0071)  time: 1.0817  data: 0.0002  max mem: 5137
# Epoch: [4]  [169/170]  eta: 0:00:01.087152  lr: 0.006600  loss: 0.1826 (0.2202)  loss_classifier: 0.0494 (0.0699)  loss_box_reg: 0.1289 (0.1391)  loss_objectness: 0.0006 (0.0043)  loss_rpn_box_reg: 0.0038 (0.0069)  time: 1.0666  data: 0.0002  max mem: 5137
# Epoch: [4] Total time: 0:03:04 (1.0875 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.390754  model_time: 0.1081 (0.1081)  evaluator_time: 0.0016 (0.0016)  time: 0.2752  data: 0.1649  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.117399  model_time: 0.1076 (0.1122)  evaluator_time: 0.0008 (0.0028)  time: 0.1151  data: 0.0002  max mem: 5137
# Test:  Total time: 0:00:10 (0.1180 s / it)
# Averaged stats: model_time: 0.1076 (0.1122)  evaluator_time: 0.0008 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.733
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.567
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.702
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.817
# Epoch: [5]  [  0/170]  eta: 0:03:53.399122  lr: 0.006600  loss: 0.3980 (0.3980)  loss_classifier: 0.1472 (0.1472)  loss_box_reg: 0.2390 (0.2390)  loss_objectness: 0.0026 (0.0026)  loss_rpn_box_reg: 0.0093 (0.0093)  time: 1.3729  data: 0.2455  max mem: 5137
# Epoch: [5]  [ 50/170]  eta: 0:02:09.603588  lr: 0.006600  loss: 0.1238 (0.2113)  loss_classifier: 0.0343 (0.0645)  loss_box_reg: 0.0860 (0.1352)  loss_objectness: 0.0013 (0.0054)  loss_rpn_box_reg: 0.0023 (0.0061)  time: 1.0802  data: 0.0002  max mem: 5137
# Epoch: [5]  [100/170]  eta: 0:01:15.510600  lr: 0.006600  loss: 0.1539 (0.2022)  loss_classifier: 0.0414 (0.0611)  loss_box_reg: 0.1102 (0.1309)  loss_objectness: 0.0007 (0.0038)  loss_rpn_box_reg: 0.0016 (0.0062)  time: 1.0895  data: 0.0002  max mem: 5137
# Epoch: [5]  [150/170]  eta: 0:00:21.538315  lr: 0.006600  loss: 0.0649 (0.2014)  loss_classifier: 0.0329 (0.0617)  loss_box_reg: 0.0288 (0.1288)  loss_objectness: 0.0029 (0.0043)  loss_rpn_box_reg: 0.0003 (0.0066)  time: 1.0632  data: 0.0002  max mem: 5137
# Epoch: [5]  [169/170]  eta: 0:00:01.077406  lr: 0.006600  loss: 0.1626 (0.2040)  loss_classifier: 0.0711 (0.0632)  loss_box_reg: 0.0893 (0.1296)  loss_objectness: 0.0008 (0.0045)  loss_rpn_box_reg: 0.0014 (0.0068)  time: 1.0821  data: 0.0003  max mem: 5137
# Epoch: [5] Total time: 0:03:03 (1.0778 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.293176  model_time: 0.1092 (0.1092)  evaluator_time: 0.0018 (0.0018)  time: 0.2740  data: 0.1623  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.117157  model_time: 0.1093 (0.1117)  evaluator_time: 0.0008 (0.0031)  time: 0.1144  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1178 s / it)
# Averaged stats: model_time: 0.1093 (0.1117)  evaluator_time: 0.0008 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.729
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.506
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.609
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.851
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.541
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.698
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.871
# Epoch: [6]  [  0/170]  eta: 0:03:52.616668  lr: 0.002178  loss: 0.3212 (0.3212)  loss_classifier: 0.0858 (0.0858)  loss_box_reg: 0.2225 (0.2225)  loss_objectness: 0.0057 (0.0057)  loss_rpn_box_reg: 0.0072 (0.0072)  time: 1.3683  data: 0.2223  max mem: 5137
# Epoch: [6]  [ 50/170]  eta: 0:02:08.992429  lr: 0.002178  loss: 0.3115 (0.1926)  loss_classifier: 0.0906 (0.0609)  loss_box_reg: 0.2114 (0.1205)  loss_objectness: 0.0011 (0.0039)  loss_rpn_box_reg: 0.0085 (0.0073)  time: 1.0735  data: 0.0002  max mem: 5137
# Epoch: [6]  [100/170]  eta: 0:01:14.801425  lr: 0.002178  loss: 0.0363 (0.1809)  loss_classifier: 0.0109 (0.0569)  loss_box_reg: 0.0196 (0.1152)  loss_objectness: 0.0055 (0.0030)  loss_rpn_box_reg: 0.0003 (0.0058)  time: 1.0665  data: 0.0002  max mem: 5137
# Epoch: [6]  [150/170]  eta: 0:00:21.469659  lr: 0.002178  loss: 0.1035 (0.1852)  loss_classifier: 0.0391 (0.0578)  loss_box_reg: 0.0630 (0.1185)  loss_objectness: 0.0003 (0.0031)  loss_rpn_box_reg: 0.0011 (0.0058)  time: 1.0880  data: 0.0002  max mem: 5137
# Epoch: [6]  [169/170]  eta: 0:00:01.070605  lr: 0.002178  loss: 0.0361 (0.1809)  loss_classifier: 0.0126 (0.0568)  loss_box_reg: 0.0224 (0.1156)  loss_objectness: 0.0003 (0.0030)  loss_rpn_box_reg: 0.0008 (0.0055)  time: 1.0517  data: 0.0002  max mem: 5137
# Epoch: [6] Total time: 0:03:02 (1.0710 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.296114  model_time: 0.1107 (0.1107)  evaluator_time: 0.0018 (0.0018)  time: 0.2741  data: 0.1610  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.117499  model_time: 0.1088 (0.1124)  evaluator_time: 0.0009 (0.0028)  time: 0.1144  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1182 s / it)
# Averaged stats: model_time: 0.1088 (0.1124)  evaluator_time: 0.0009 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.526
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.793
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.644
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.729
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.891
# Epoch: [7]  [  0/170]  eta: 0:04:17.610126  lr: 0.002178  loss: 0.1986 (0.1986)  loss_classifier: 0.0530 (0.0530)  loss_box_reg: 0.1338 (0.1338)  loss_objectness: 0.0030 (0.0030)  loss_rpn_box_reg: 0.0088 (0.0088)  time: 1.5154  data: 0.2949  max mem: 5137
# Epoch: [7]  [ 50/170]  eta: 0:02:09.841653  lr: 0.002178  loss: 0.0484 (0.1741)  loss_classifier: 0.0157 (0.0533)  loss_box_reg: 0.0318 (0.1113)  loss_objectness: 0.0002 (0.0027)  loss_rpn_box_reg: 0.0006 (0.0069)  time: 1.0695  data: 0.0002  max mem: 5137
# Epoch: [7]  [100/170]  eta: 0:01:15.338391  lr: 0.002178  loss: 0.1965 (0.1722)  loss_classifier: 0.0441 (0.0538)  loss_box_reg: 0.1444 (0.1101)  loss_objectness: 0.0020 (0.0026)  loss_rpn_box_reg: 0.0060 (0.0057)  time: 1.0695  data: 0.0002  max mem: 5137
# Epoch: [7]  [150/170]  eta: 0:00:21.534878  lr: 0.002178  loss: 0.3388 (0.1728)  loss_classifier: 0.1224 (0.0536)  loss_box_reg: 0.2033 (0.1112)  loss_objectness: 0.0039 (0.0026)  loss_rpn_box_reg: 0.0092 (0.0054)  time: 1.0772  data: 0.0002  max mem: 5137
# Epoch: [7]  [169/170]  eta: 0:00:01.073304  lr: 0.002178  loss: 0.0888 (0.1722)  loss_classifier: 0.0272 (0.0537)  loss_box_reg: 0.0598 (0.1106)  loss_objectness: 0.0002 (0.0025)  loss_rpn_box_reg: 0.0016 (0.0054)  time: 1.0500  data: 0.0002  max mem: 5137
# Epoch: [7] Total time: 0:03:02 (1.0737 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.565444  model_time: 0.1094 (0.1094)  evaluator_time: 0.0015 (0.0015)  time: 0.2772  data: 0.1658  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.116687  model_time: 0.1073 (0.1115)  evaluator_time: 0.0008 (0.0027)  time: 0.1140  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:09 (0.1174 s / it)
# Averaged stats: model_time: 0.1073 (0.1115)  evaluator_time: 0.0008 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.524
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.806
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.604
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.442
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.650
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.835
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.578
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.577
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.864
# Epoch: [8]  [  0/170]  eta: 0:03:36.701460  lr: 0.002178  loss: 0.0318 (0.0318)  loss_classifier: 0.0122 (0.0122)  loss_box_reg: 0.0182 (0.0182)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 1.2747  data: 0.2699  max mem: 5137
# Epoch: [8]  [ 50/170]  eta: 0:02:08.214652  lr: 0.002178  loss: 0.2912 (0.1601)  loss_classifier: 0.1008 (0.0472)  loss_box_reg: 0.1807 (0.1075)  loss_objectness: 0.0028 (0.0014)  loss_rpn_box_reg: 0.0069 (0.0040)  time: 1.0734  data: 0.0002  max mem: 5137
# Epoch: [8]  [100/170]  eta: 0:01:15.370322  lr: 0.002178  loss: 0.1050 (0.1652)  loss_classifier: 0.0305 (0.0499)  loss_box_reg: 0.0702 (0.1089)  loss_objectness: 0.0011 (0.0020)  loss_rpn_box_reg: 0.0032 (0.0045)  time: 1.0803  data: 0.0002  max mem: 5137
# Epoch: [8]  [150/170]  eta: 0:00:21.580246  lr: 0.002178  loss: 0.1811 (0.1675)  loss_classifier: 0.0508 (0.0503)  loss_box_reg: 0.1262 (0.1093)  loss_objectness: 0.0009 (0.0025)  loss_rpn_box_reg: 0.0031 (0.0053)  time: 1.0915  data: 0.0002  max mem: 5137
# Epoch: [8]  [169/170]  eta: 0:00:01.074875  lr: 0.002178  loss: 0.0583 (0.1630)  loss_classifier: 0.0212 (0.0497)  loss_box_reg: 0.0359 (0.1059)  loss_objectness: 0.0007 (0.0023)  loss_rpn_box_reg: 0.0005 (0.0051)  time: 1.0491  data: 0.0002  max mem: 5137
# Epoch: [8] Total time: 0:03:02 (1.0752 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.844095  model_time: 0.1118 (0.1118)  evaluator_time: 0.0017 (0.0017)  time: 0.2805  data: 0.1662  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.117322  model_time: 0.1074 (0.1122)  evaluator_time: 0.0009 (0.0027)  time: 0.1145  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1180 s / it)
# Averaged stats: model_time: 0.1074 (0.1122)  evaluator_time: 0.0009 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.528
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.812
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.629
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.635
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.858
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.623
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.699
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.884
# Epoch: [9]  [  0/170]  eta: 0:03:48.284535  lr: 0.000719  loss: 0.0304 (0.0304)  loss_classifier: 0.0132 (0.0132)  loss_box_reg: 0.0166 (0.0166)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 1.3429  data: 0.2242  max mem: 5137
# Epoch: [9]  [ 50/170]  eta: 0:02:10.436457  lr: 0.000719  loss: 0.1041 (0.1640)  loss_classifier: 0.0292 (0.0497)  loss_box_reg: 0.0722 (0.1057)  loss_objectness: 0.0007 (0.0024)  loss_rpn_box_reg: 0.0020 (0.0062)  time: 1.0924  data: 0.0002  max mem: 5137
# Epoch: [9]  [100/170]  eta: 0:01:15.520726  lr: 0.000719  loss: 0.3457 (0.1678)  loss_classifier: 0.1390 (0.0522)  loss_box_reg: 0.1902 (0.1078)  loss_objectness: 0.0076 (0.0024)  loss_rpn_box_reg: 0.0089 (0.0055)  time: 1.0883  data: 0.0002  max mem: 5137
# Epoch: [9]  [150/170]  eta: 0:00:21.510554  lr: 0.000719  loss: 0.0324 (0.1610)  loss_classifier: 0.0101 (0.0504)  loss_box_reg: 0.0219 (0.1033)  loss_objectness: 0.0001 (0.0021)  loss_rpn_box_reg: 0.0003 (0.0052)  time: 1.0809  data: 0.0002  max mem: 5137
# Epoch: [9]  [169/170]  eta: 0:00:01.074399  lr: 0.000719  loss: 0.0629 (0.1589)  loss_classifier: 0.0282 (0.0496)  loss_box_reg: 0.0342 (0.1020)  loss_objectness: 0.0001 (0.0022)  loss_rpn_box_reg: 0.0005 (0.0050)  time: 1.0670  data: 0.0002  max mem: 5137
# Epoch: [9] Total time: 0:03:02 (1.0748 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:24.251859  model_time: 0.1110 (0.1110)  evaluator_time: 0.0016 (0.0016)  time: 0.2853  data: 0.1720  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.118814  model_time: 0.1092 (0.1136)  evaluator_time: 0.0008 (0.0027)  time: 0.1161  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1194 s / it)
# Averaged stats: model_time: 0.1092 (0.1136)  evaluator_time: 0.0008 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.522
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.809
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.618
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.447
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.657
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.859
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.616
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.716
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.881
# Epoch: [10]  [  0/170]  eta: 0:03:42.036414  lr: 0.000719  loss: 0.0366 (0.0366)  loss_classifier: 0.0158 (0.0158)  loss_box_reg: 0.0204 (0.0204)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 1.3061  data: 0.2564  max mem: 5137
# Epoch: [10]  [ 50/170]  eta: 0:02:10.463907  lr: 0.000719  loss: 0.3543 (0.1522)  loss_classifier: 0.0867 (0.0447)  loss_box_reg: 0.2395 (0.0989)  loss_objectness: 0.0100 (0.0029)  loss_rpn_box_reg: 0.0181 (0.0057)  time: 1.0829  data: 0.0002  max mem: 5137
# Epoch: [10]  [100/170]  eta: 0:01:15.583760  lr: 0.000719  loss: 0.1921 (0.1572)  loss_classifier: 0.0492 (0.0471)  loss_box_reg: 0.1376 (0.1023)  loss_objectness: 0.0018 (0.0025)  loss_rpn_box_reg: 0.0034 (0.0053)  time: 1.0633  data: 0.0002  max mem: 5137
# Epoch: [10]  [150/170]  eta: 0:00:21.520167  lr: 0.000719  loss: 0.2219 (0.1538)  loss_classifier: 0.0543 (0.0457)  loss_box_reg: 0.1517 (0.1008)  loss_objectness: 0.0022 (0.0023)  loss_rpn_box_reg: 0.0137 (0.0050)  time: 1.0639  data: 0.0002  max mem: 5137
# Epoch: [10]  [169/170]  eta: 0:00:01.075173  lr: 0.000719  loss: 0.0850 (0.1538)  loss_classifier: 0.0306 (0.0464)  loss_box_reg: 0.0508 (0.1003)  loss_objectness: 0.0023 (0.0023)  loss_rpn_box_reg: 0.0013 (0.0049)  time: 1.0682  data: 0.0002  max mem: 5137
# Epoch: [10] Total time: 0:03:02 (1.0755 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:24.422860  model_time: 0.1116 (0.1116)  evaluator_time: 0.0015 (0.0015)  time: 0.2873  data: 0.1736  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.117923  model_time: 0.1094 (0.1128)  evaluator_time: 0.0008 (0.0026)  time: 0.1143  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1186 s / it)
# Averaged stats: model_time: 0.1094 (0.1128)  evaluator_time: 0.0008 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.806
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.611
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.659
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.865
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.731
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.883
# Epoch: [11]  [  0/170]  eta: 0:03:52.336719  lr: 0.000719  loss: 0.1130 (0.1130)  loss_classifier: 0.0268 (0.0268)  loss_box_reg: 0.0848 (0.0848)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0011 (0.0011)  time: 1.3667  data: 0.2462  max mem: 5137
# Epoch: [11]  [ 50/170]  eta: 0:02:09.601510  lr: 0.000719  loss: 0.1046 (0.1523)  loss_classifier: 0.0353 (0.0452)  loss_box_reg: 0.0676 (0.0987)  loss_objectness: 0.0001 (0.0026)  loss_rpn_box_reg: 0.0015 (0.0058)  time: 1.0749  data: 0.0002  max mem: 5137
# Epoch: [11]  [100/170]  eta: 0:01:15.354244  lr: 0.000719  loss: 0.0316 (0.1505)  loss_classifier: 0.0117 (0.0456)  loss_box_reg: 0.0195 (0.0982)  loss_objectness: 0.0000 (0.0020)  loss_rpn_box_reg: 0.0003 (0.0047)  time: 1.0581  data: 0.0002  max mem: 5137
# Epoch: [11]  [150/170]  eta: 0:00:21.574187  lr: 0.000719  loss: 0.2149 (0.1488)  loss_classifier: 0.0615 (0.0458)  loss_box_reg: 0.1488 (0.0971)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0040 (0.0042)  time: 1.1051  data: 0.0002  max mem: 5137
# Epoch: [11]  [169/170]  eta: 0:00:01.076809  lr: 0.000719  loss: 0.1210 (0.1513)  loss_classifier: 0.0377 (0.0467)  loss_box_reg: 0.0816 (0.0982)  loss_objectness: 0.0001 (0.0018)  loss_rpn_box_reg: 0.0016 (0.0046)  time: 1.0649  data: 0.0002  max mem: 5137
# Epoch: [11] Total time: 0:03:03 (1.0772 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:22.850474  model_time: 0.1122 (0.1122)  evaluator_time: 0.0016 (0.0016)  time: 0.2688  data: 0.1543  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.116774  model_time: 0.1093 (0.1119)  evaluator_time: 0.0008 (0.0026)  time: 0.1133  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:09 (0.1174 s / it)
# Averaged stats: model_time: 0.1093 (0.1119)  evaluator_time: 0.0008 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.797
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.639
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.619
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.876
# Epoch: [12]  [  0/170]  eta: 0:03:43.302972  lr: 0.000237  loss: 0.1615 (0.1615)  loss_classifier: 0.0553 (0.0553)  loss_box_reg: 0.1006 (0.1006)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0048 (0.0048)  time: 1.3135  data: 0.2271  max mem: 5137
# Epoch: [12]  [ 50/170]  eta: 0:02:07.327595  lr: 0.000237  loss: 0.0909 (0.1482)  loss_classifier: 0.0268 (0.0452)  loss_box_reg: 0.0618 (0.0951)  loss_objectness: 0.0007 (0.0025)  loss_rpn_box_reg: 0.0017 (0.0054)  time: 1.0452  data: 0.0002  max mem: 5137
# Epoch: [12]  [100/170]  eta: 0:01:14.842300  lr: 0.000237  loss: 0.2780 (0.1458)  loss_classifier: 0.0836 (0.0441)  loss_box_reg: 0.1689 (0.0942)  loss_objectness: 0.0096 (0.0020)  loss_rpn_box_reg: 0.0159 (0.0056)  time: 1.0932  data: 0.0002  max mem: 5137
# Epoch: [12]  [150/170]  eta: 0:00:21.517160  lr: 0.000237  loss: 0.1780 (0.1486)  loss_classifier: 0.0542 (0.0453)  loss_box_reg: 0.1218 (0.0965)  loss_objectness: 0.0005 (0.0019)  loss_rpn_box_reg: 0.0015 (0.0048)  time: 1.0730  data: 0.0003  max mem: 5137
# Epoch: [12]  [169/170]  eta: 0:00:01.073923  lr: 0.000237  loss: 0.1127 (0.1468)  loss_classifier: 0.0417 (0.0451)  loss_box_reg: 0.0696 (0.0950)  loss_objectness: 0.0002 (0.0020)  loss_rpn_box_reg: 0.0011 (0.0047)  time: 1.0622  data: 0.0002  max mem: 5137
# Epoch: [12] Total time: 0:03:02 (1.0743 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:22.889526  model_time: 0.1092 (0.1092)  evaluator_time: 0.0015 (0.0015)  time: 0.2693  data: 0.1581  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.117055  model_time: 0.1091 (0.1121)  evaluator_time: 0.0008 (0.0026)  time: 0.1143  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1177 s / it)
# Averaged stats: model_time: 0.1091 (0.1121)  evaluator_time: 0.0008 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.522
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.803
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.600
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.645
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.873
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.621
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.906
# Epoch: [13]  [  0/170]  eta: 0:03:58.500941  lr: 0.000237  loss: 0.2156 (0.2156)  loss_classifier: 0.0544 (0.0544)  loss_box_reg: 0.1518 (0.1518)  loss_objectness: 0.0038 (0.0038)  loss_rpn_box_reg: 0.0057 (0.0057)  time: 1.4029  data: 0.2671  max mem: 5137
# Epoch: [13]  [ 50/170]  eta: 0:02:09.734586  lr: 0.000237  loss: 0.1117 (0.1492)  loss_classifier: 0.0497 (0.0458)  loss_box_reg: 0.0604 (0.0975)  loss_objectness: 0.0001 (0.0016)  loss_rpn_box_reg: 0.0015 (0.0043)  time: 1.0518  data: 0.0002  max mem: 5137
# Epoch: [13]  [100/170]  eta: 0:01:15.709100  lr: 0.000237  loss: 0.1401 (0.1515)  loss_classifier: 0.0484 (0.0460)  loss_box_reg: 0.0855 (0.0994)  loss_objectness: 0.0021 (0.0018)  loss_rpn_box_reg: 0.0041 (0.0044)  time: 1.0816  data: 0.0002  max mem: 5137
# Epoch: [13]  [150/170]  eta: 0:00:21.571812  lr: 0.000237  loss: 0.1180 (0.1493)  loss_classifier: 0.0440 (0.0454)  loss_box_reg: 0.0705 (0.0973)  loss_objectness: 0.0010 (0.0018)  loss_rpn_box_reg: 0.0027 (0.0048)  time: 1.0822  data: 0.0002  max mem: 5137
# Epoch: [13]  [169/170]  eta: 0:00:01.075447  lr: 0.000237  loss: 0.0747 (0.1474)  loss_classifier: 0.0288 (0.0452)  loss_box_reg: 0.0447 (0.0955)  loss_objectness: 0.0001 (0.0020)  loss_rpn_box_reg: 0.0011 (0.0047)  time: 1.0528  data: 0.0002  max mem: 5137
# Epoch: [13] Total time: 0:03:02 (1.0758 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.329107  model_time: 0.1116 (0.1116)  evaluator_time: 0.0016 (0.0016)  time: 0.2745  data: 0.1608  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.117078  model_time: 0.1097 (0.1121)  evaluator_time: 0.0010 (0.0026)  time: 0.1141  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:10 (0.1178 s / it)
# Averaged stats: model_time: 0.1097 (0.1121)  evaluator_time: 0.0010 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.797
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.458
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.873
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.577
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.706
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.906
# Epoch: [14]  [  0/170]  eta: 0:03:55.829775  lr: 0.000237  loss: 0.1969 (0.1969)  loss_classifier: 0.0510 (0.0510)  loss_box_reg: 0.1410 (0.1410)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 1.3872  data: 0.2252  max mem: 5137
# Epoch: [14]  [ 50/170]  eta: 0:02:10.639710  lr: 0.000237  loss: 0.1194 (0.1454)  loss_classifier: 0.0392 (0.0446)  loss_box_reg: 0.0767 (0.0947)  loss_objectness: 0.0009 (0.0015)  loss_rpn_box_reg: 0.0026 (0.0047)  time: 1.0910  data: 0.0002  max mem: 5137
# Epoch: [14]  [100/170]  eta: 0:01:15.513630  lr: 0.000237  loss: 0.0560 (0.1419)  loss_classifier: 0.0191 (0.0436)  loss_box_reg: 0.0342 (0.0925)  loss_objectness: 0.0017 (0.0016)  loss_rpn_box_reg: 0.0011 (0.0042)  time: 1.0654  data: 0.0002  max mem: 5137
# Epoch: [14]  [150/170]  eta: 0:00:21.622577  lr: 0.000237  loss: 0.0846 (0.1477)  loss_classifier: 0.0296 (0.0449)  loss_box_reg: 0.0533 (0.0960)  loss_objectness: 0.0001 (0.0020)  loss_rpn_box_reg: 0.0016 (0.0048)  time: 1.0865  data: 0.0002  max mem: 5137
# Epoch: [14]  [169/170]  eta: 0:00:01.079926  lr: 0.000237  loss: 0.1070 (0.1463)  loss_classifier: 0.0474 (0.0446)  loss_box_reg: 0.0577 (0.0951)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0013 (0.0046)  time: 1.0637  data: 0.0003  max mem: 5137
# Epoch: [14] Total time: 0:03:03 (1.0803 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.809664  model_time: 0.1104 (0.1104)  evaluator_time: 0.0035 (0.0035)  time: 0.2801  data: 0.1656  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.116911  model_time: 0.1068 (0.1119)  evaluator_time: 0.0008 (0.0026)  time: 0.1145  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:09 (0.1176 s / it)
# Averaged stats: model_time: 0.1068 (0.1119)  evaluator_time: 0.0008 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.798
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.599
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.453
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.639
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.870
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.618
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.906
# Epoch: [15]  [  0/170]  eta: 0:03:45.379424  lr: 0.000078  loss: 0.0408 (0.0408)  loss_classifier: 0.0163 (0.0163)  loss_box_reg: 0.0238 (0.0238)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 1.3258  data: 0.2834  max mem: 5137
# Epoch: [15]  [ 50/170]  eta: 0:02:10.183755  lr: 0.000078  loss: 0.1771 (0.1402)  loss_classifier: 0.0486 (0.0418)  loss_box_reg: 0.1191 (0.0934)  loss_objectness: 0.0053 (0.0015)  loss_rpn_box_reg: 0.0041 (0.0035)  time: 1.0702  data: 0.0002  max mem: 5137
# Epoch: [15]  [100/170]  eta: 0:01:15.636326  lr: 0.000078  loss: 0.0827 (0.1522)  loss_classifier: 0.0216 (0.0456)  loss_box_reg: 0.0598 (0.0992)  loss_objectness: 0.0004 (0.0022)  loss_rpn_box_reg: 0.0010 (0.0052)  time: 1.0854  data: 0.0002  max mem: 5137
# Epoch: [15]  [150/170]  eta: 0:00:21.657702  lr: 0.000078  loss: 0.0333 (0.1495)  loss_classifier: 0.0097 (0.0448)  loss_box_reg: 0.0233 (0.0979)  loss_objectness: 0.0000 (0.0021)  loss_rpn_box_reg: 0.0003 (0.0048)  time: 1.0952  data: 0.0002  max mem: 5137
# Epoch: [15]  [169/170]  eta: 0:00:01.081741  lr: 0.000078  loss: 0.0671 (0.1463)  loss_classifier: 0.0240 (0.0441)  loss_box_reg: 0.0420 (0.0955)  loss_objectness: 0.0003 (0.0020)  loss_rpn_box_reg: 0.0009 (0.0046)  time: 1.0622  data: 0.0002  max mem: 5137
# Epoch: [15] Total time: 0:03:03 (1.0821 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:22.572207  model_time: 0.1094 (0.1094)  evaluator_time: 0.0014 (0.0014)  time: 0.2656  data: 0.1539  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.116744  model_time: 0.1106 (0.1119)  evaluator_time: 0.0008 (0.0026)  time: 0.1141  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:09 (0.1174 s / it)
# Averaged stats: model_time: 0.1106 (0.1119)  evaluator_time: 0.0008 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.799
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.636
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.886
# Epoch: [16]  [  0/170]  eta: 0:03:36.584284  lr: 0.000078  loss: 0.0295 (0.0295)  loss_classifier: 0.0103 (0.0103)  loss_box_reg: 0.0150 (0.0150)  loss_objectness: 0.0041 (0.0041)  loss_rpn_box_reg: 0.0001 (0.0001)  time: 1.2740  data: 0.2465  max mem: 5137
# Epoch: [16]  [ 50/170]  eta: 0:02:08.068939  lr: 0.000078  loss: 0.1230 (0.1447)  loss_classifier: 0.0554 (0.0435)  loss_box_reg: 0.0660 (0.0943)  loss_objectness: 0.0001 (0.0014)  loss_rpn_box_reg: 0.0014 (0.0056)  time: 1.0503  data: 0.0002  max mem: 5137
# Epoch: [16]  [100/170]  eta: 0:01:15.305782  lr: 0.000078  loss: 0.1110 (0.1485)  loss_classifier: 0.0495 (0.0446)  loss_box_reg: 0.0601 (0.0967)  loss_objectness: 0.0003 (0.0020)  loss_rpn_box_reg: 0.0011 (0.0052)  time: 1.0815  data: 0.0002  max mem: 5137
# Epoch: [16]  [150/170]  eta: 0:00:21.507159  lr: 0.000078  loss: 0.1815 (0.1447)  loss_classifier: 0.0542 (0.0436)  loss_box_reg: 0.1224 (0.0943)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0039 (0.0047)  time: 1.0757  data: 0.0002  max mem: 5137
# Epoch: [16]  [169/170]  eta: 0:00:01.071861  lr: 0.000078  loss: 0.0752 (0.1442)  loss_classifier: 0.0230 (0.0437)  loss_box_reg: 0.0510 (0.0941)  loss_objectness: 0.0003 (0.0019)  loss_rpn_box_reg: 0.0008 (0.0045)  time: 1.0487  data: 0.0002  max mem: 5137
# Epoch: [16] Total time: 0:03:02 (1.0722 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:22.883041  model_time: 0.1083 (0.1083)  evaluator_time: 0.0015 (0.0015)  time: 0.2692  data: 0.1588  max mem: 5137
# Test:   [84/85]  eta: 0:00:00.116806  model_time: 0.1074 (0.1119)  evaluator_time: 0.0008 (0.0026)  time: 0.1143  data: 0.0001  max mem: 5137
# Test:  Total time: 0:00:09 (0.1175 s / it)
# Averaged stats: model_time: 0.1074 (0.1119)  evaluator_time: 0.0008 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.798
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.602
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.639
# ...
# Epoch: [24]  [169/170]  eta: 0:00:01.073957  lr: 0.000003  loss: 0.0529 (0.1438)  loss_classifier: 0.0152 (0.0436)  loss_box_reg: 0.0364 (0.0934)  loss_objectness: 0.0007 (0.0023)  loss_rpn_box_reg: 0.0006 (0.0046)  time: 1.0486  data: 0.0002  max mem: 5138
# Epoch: [24] Total time: 0:03:02 (1.0743 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:24.511137  model_time: 0.1103 (0.1103)  evaluator_time: 0.0016 (0.0016)  time: 0.2884  data: 0.1759  max mem: 5138
# Test:   [84/85]  eta: 0:00:00.117853  model_time: 0.1083 (0.1125)  evaluator_time: 0.0009 (0.0028)  time: 0.1145  data: 0.0001  max mem: 5138
# Test:  Total time: 0:00:10 (0.1186 s / it)
# Averaged stats: model_time: 0.1083 (0.1125)  evaluator_time: 0.0009 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.457
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.876
# Epoch: [25]  [  0/170]  eta: 0:03:54.436841  lr: 0.000003  loss: 0.1381 (0.1381)  loss_classifier: 0.0330 (0.0330)  loss_box_reg: 0.0981 (0.0981)  loss_objectness: 0.0054 (0.0054)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 1.3790  data: 0.2524  max mem: 5138
# Epoch: [25]  [ 50/170]  eta: 0:02:09.013268  lr: 0.000003  loss: 0.0357 (0.1400)  loss_classifier: 0.0151 (0.0414)  loss_box_reg: 0.0204 (0.0934)  loss_objectness: 0.0000 (0.0016)  loss_rpn_box_reg: 0.0002 (0.0037)  time: 1.0826  data: 0.0002  max mem: 5138
# Epoch: [25]  [100/170]  eta: 0:01:15.945425  lr: 0.000003  loss: 0.2538 (0.1522)  loss_classifier: 0.0761 (0.0453)  loss_box_reg: 0.1706 (0.0987)  loss_objectness: 0.0011 (0.0027)  loss_rpn_box_reg: 0.0060 (0.0055)  time: 1.0870  data: 0.0002  max mem: 5138
# Epoch: [25]  [150/170]  eta: 0:00:21.578676  lr: 0.000003  loss: 0.2826 (0.1434)  loss_classifier: 0.0784 (0.0432)  loss_box_reg: 0.1749 (0.0933)  loss_objectness: 0.0134 (0.0023)  loss_rpn_box_reg: 0.0158 (0.0047)  time: 1.0671  data: 0.0002  max mem: 5138
# Epoch: [25]  [169/170]  eta: 0:00:01.074376  lr: 0.000003  loss: 0.0394 (0.1425)  loss_classifier: 0.0131 (0.0431)  loss_box_reg: 0.0256 (0.0927)  loss_objectness: 0.0001 (0.0022)  loss_rpn_box_reg: 0.0006 (0.0045)  time: 1.0426  data: 0.0002  max mem: 5138
# Epoch: [25] Total time: 0:03:02 (1.0748 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:23.121182  model_time: 0.1100 (0.1100)  evaluator_time: 0.0017 (0.0017)  time: 0.2720  data: 0.1596  max mem: 5138
# Test:   [84/85]  eta: 0:00:00.117158  model_time: 0.1096 (0.1122)  evaluator_time: 0.0008 (0.0026)  time: 0.1142  data: 0.0001  max mem: 5138
# Test:  Total time: 0:00:10 (0.1179 s / it)
# Averaged stats: model_time: 0.1096 (0.1122)  evaluator_time: 0.0008 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.613
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.886
# Epoch: [26]  [  0/170]  eta: 0:03:55.580103  lr: 0.000003  loss: 0.1111 (0.1111)  loss_classifier: 0.0413 (0.0413)  loss_box_reg: 0.0684 (0.0684)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 1.3858  data: 0.2521  max mem: 5138
# Epoch: [26]  [ 50/170]  eta: 0:02:08.651505  lr: 0.000003  loss: 0.0288 (0.1463)  loss_classifier: 0.0093 (0.0446)  loss_box_reg: 0.0190 (0.0958)  loss_objectness: 0.0000 (0.0017)  loss_rpn_box_reg: 0.0004 (0.0042)  time: 1.0854  data: 0.0002  max mem: 5138
# Epoch: [26]  [100/170]  eta: 0:01:14.906395  lr: 0.000003  loss: 0.2329 (0.1439)  loss_classifier: 0.0915 (0.0440)  loss_box_reg: 0.1360 (0.0940)  loss_objectness: 0.0008 (0.0018)  loss_rpn_box_reg: 0.0046 (0.0042)  time: 1.0744  data: 0.0002  max mem: 5138
# Epoch: [26]  [150/170]  eta: 0:00:21.502349  lr: 0.000003  loss: 0.0412 (0.1469)  loss_classifier: 0.0135 (0.0445)  loss_box_reg: 0.0256 (0.0959)  loss_objectness: 0.0017 (0.0021)  loss_rpn_box_reg: 0.0004 (0.0044)  time: 1.0811  data: 0.0002  max mem: 5138
# Epoch: [26]  [169/170]  eta: 0:00:01.071218  lr: 0.000003  loss: 0.0418 (0.1430)  loss_classifier: 0.0109 (0.0433)  loss_box_reg: 0.0297 (0.0930)  loss_objectness: 0.0001 (0.0020)  loss_rpn_box_reg: 0.0010 (0.0047)  time: 1.0425  data: 0.0002  max mem: 5138
# Epoch: [26] Total time: 0:03:02 (1.0716 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:22.728394  model_time: 0.1075 (0.1075)  evaluator_time: 0.0015 (0.0015)  time: 0.2674  data: 0.1577  max mem: 5138
# Test:   [84/85]  eta: 0:00:00.116524  model_time: 0.1067 (0.1117)  evaluator_time: 0.0007 (0.0025)  time: 0.1136  data: 0.0001  max mem: 5138
# Test:  Total time: 0:00:09 (0.1172 s / it)
# Averaged stats: model_time: 0.1067 (0.1117)  evaluator_time: 0.0007 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.876
# Epoch: [27]  [  0/170]  eta: 0:03:48.511915  lr: 0.000001  loss: 0.1603 (0.1603)  loss_classifier: 0.0705 (0.0705)  loss_box_reg: 0.0871 (0.0871)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0022 (0.0022)  time: 1.3442  data: 0.2324  max mem: 5138
# Epoch: [27]  [ 50/170]  eta: 0:02:08.037298  lr: 0.000001  loss: 0.0289 (0.1487)  loss_classifier: 0.0097 (0.0450)  loss_box_reg: 0.0189 (0.0959)  loss_objectness: 0.0001 (0.0017)  loss_rpn_box_reg: 0.0003 (0.0061)  time: 1.0603  data: 0.0002  max mem: 5138
# Epoch: [27]  [100/170]  eta: 0:01:14.730315  lr: 0.000001  loss: 0.0515 (0.1401)  loss_classifier: 0.0205 (0.0426)  loss_box_reg: 0.0305 (0.0910)  loss_objectness: 0.0000 (0.0016)  loss_rpn_box_reg: 0.0004 (0.0049)  time: 1.0662  data: 0.0002  max mem: 5138
# Epoch: [27]  [150/170]  eta: 0:00:21.402447  lr: 0.000001  loss: 0.2814 (0.1434)  loss_classifier: 0.0870 (0.0435)  loss_box_reg: 0.1789 (0.0932)  loss_objectness: 0.0022 (0.0018)  loss_rpn_box_reg: 0.0133 (0.0048)  time: 1.0820  data: 0.0002  max mem: 5138
# Epoch: [27]  [169/170]  eta: 0:00:01.069178  lr: 0.000001  loss: 0.0610 (0.1436)  loss_classifier: 0.0184 (0.0440)  loss_box_reg: 0.0413 (0.0931)  loss_objectness: 0.0002 (0.0018)  loss_rpn_box_reg: 0.0012 (0.0047)  time: 1.0591  data: 0.0002  max mem: 5138
# Epoch: [27] Total time: 0:03:01 (1.0696 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:22.883081  model_time: 0.1093 (0.1093)  evaluator_time: 0.0014 (0.0014)  time: 0.2692  data: 0.1579  max mem: 5138
# Test:   [84/85]  eta: 0:00:00.116165  model_time: 0.1088 (0.1113)  evaluator_time: 0.0009 (0.0026)  time: 0.1132  data: 0.0001  max mem: 5138
# Test:  Total time: 0:00:09 (0.1169 s / it)
# Averaged stats: model_time: 0.1088 (0.1113)  evaluator_time: 0.0009 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.876
# Epoch: [28]  [  0/170]  eta: 0:03:55.178318  lr: 0.000001  loss: 0.1647 (0.1647)  loss_classifier: 0.0453 (0.0453)  loss_box_reg: 0.1114 (0.1114)  loss_objectness: 0.0047 (0.0047)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 1.3834  data: 0.2558  max mem: 5138
# Epoch: [28]  [ 50/170]  eta: 0:02:08.431640  lr: 0.000001  loss: 0.0408 (0.1373)  loss_classifier: 0.0135 (0.0414)  loss_box_reg: 0.0267 (0.0882)  loss_objectness: 0.0002 (0.0024)  loss_rpn_box_reg: 0.0003 (0.0053)  time: 1.0783  data: 0.0002  max mem: 5138
# Epoch: [28]  [100/170]  eta: 0:01:14.758626  lr: 0.000001  loss: 0.2363 (0.1379)  loss_classifier: 0.0784 (0.0421)  loss_box_reg: 0.1514 (0.0893)  loss_objectness: 0.0005 (0.0020)  loss_rpn_box_reg: 0.0061 (0.0045)  time: 1.0624  data: 0.0002  max mem: 5138
# Epoch: [28]  [150/170]  eta: 0:00:21.415996  lr: 0.000001  loss: 0.1176 (0.1444)  loss_classifier: 0.0320 (0.0436)  loss_box_reg: 0.0823 (0.0942)  loss_objectness: 0.0010 (0.0019)  loss_rpn_box_reg: 0.0022 (0.0047)  time: 1.0929  data: 0.0002  max mem: 5138
# Epoch: [28]  [169/170]  eta: 0:00:01.067555  lr: 0.000001  loss: 0.0519 (0.1430)  loss_classifier: 0.0146 (0.0432)  loss_box_reg: 0.0365 (0.0931)  loss_objectness: 0.0002 (0.0020)  loss_rpn_box_reg: 0.0007 (0.0046)  time: 1.0432  data: 0.0002  max mem: 5138
# Epoch: [28] Total time: 0:03:01 (1.0679 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:22.873394  model_time: 0.1103 (0.1103)  evaluator_time: 0.0015 (0.0015)  time: 0.2691  data: 0.1567  max mem: 5138
# Test:   [84/85]  eta: 0:00:00.116012  model_time: 0.1059 (0.1112)  evaluator_time: 0.0007 (0.0025)  time: 0.1128  data: 0.0001  max mem: 5138
# Test:  Total time: 0:00:09 (0.1167 s / it)
# Averaged stats: model_time: 0.1059 (0.1112)  evaluator_time: 0.0007 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.876
# Epoch: [29]  [  0/170]  eta: 0:03:57.088227  lr: 0.000001  loss: 0.0788 (0.0788)  loss_classifier: 0.0213 (0.0213)  loss_box_reg: 0.0560 (0.0560)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0013 (0.0013)  time: 1.3946  data: 0.2819  max mem: 5138
# Epoch: [29]  [ 50/170]  eta: 0:02:09.258211  lr: 0.000001  loss: 0.1494 (0.1401)  loss_classifier: 0.0393 (0.0444)  loss_box_reg: 0.1064 (0.0902)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0029 (0.0040)  time: 1.0719  data: 0.0002  max mem: 5138
# Epoch: [29]  [100/170]  eta: 0:01:15.333363  lr: 0.000001  loss: 0.0413 (0.1431)  loss_classifier: 0.0116 (0.0443)  loss_box_reg: 0.0294 (0.0926)  loss_objectness: 0.0000 (0.0019)  loss_rpn_box_reg: 0.0003 (0.0043)  time: 1.0853  data: 0.0002  max mem: 5138
# Epoch: [29]  [150/170]  eta: 0:00:21.481932  lr: 0.000001  loss: 0.0309 (0.1438)  loss_classifier: 0.0112 (0.0443)  loss_box_reg: 0.0195 (0.0931)  loss_objectness: 0.0000 (0.0018)  loss_rpn_box_reg: 0.0002 (0.0046)  time: 1.0735  data: 0.0002  max mem: 5138
# Epoch: [29]  [169/170]  eta: 0:00:01.070432  lr: 0.000001  loss: 0.0525 (0.1421)  loss_classifier: 0.0168 (0.0440)  loss_box_reg: 0.0338 (0.0919)  loss_objectness: 0.0012 (0.0018)  loss_rpn_box_reg: 0.0006 (0.0044)  time: 1.0386  data: 0.0002  max mem: 5138
# Epoch: [29] Total time: 0:03:02 (1.0708 s / it)
# creating index...
# index created!
# Test:   [ 0/85]  eta: 0:00:24.101752  model_time: 0.1087 (0.1087)  evaluator_time: 0.0016 (0.0016)  time: 0.2836  data: 0.1725  max mem: 5138
# Test:   [84/85]  eta: 0:00:00.116454  model_time: 0.1083 (0.1115)  evaluator_time: 0.0007 (0.0025)  time: 0.1132  data: 0.0001  max mem: 5138
# Test:  Total time: 0:00:09 (0.1171 s / it)
# Averaged stats: model_time: 0.1083 (0.1115)  evaluator_time: 0.0007 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.637
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.876
# successful save loss curve!
# successful save mAP curve!
